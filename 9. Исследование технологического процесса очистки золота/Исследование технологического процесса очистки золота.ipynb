# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1><br>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Анализ данных</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Модель" data-toc-modified-id="Модель-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Модель</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Общий вывод</a></span></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# # Восстановление золота из руды

# %% [markdown]
# Необходимо подготовить прототип модели машинного обучения для «Цифры». Компания разрабатывает решения для эффективной работы промышленных предприятий.
#
# Модель должна предсказать коэффициент восстановления золота из золотосодержащей руды. Используйте данные с параметрами добычи и очистки.
#
# Модель поможет оптимизировать производство, чтобы не запускать предприятие с убыточными характеристиками.
#
# Нам нужно:
#
# 1. Подготовить данные;
# 2. Провести исследовательский анализ данных;
# 3. Построить и обучить модель.

# %% [markdown]
# **Технологический процесс**
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Rougher feed — исходное сырье\
# Rougher additions (или reagent additions) — флотационные реагенты: Xanthate, Sulphate, Depressant
#  * Xanthate — ксантогенат (промотер, или активатор флотации);
#  * Sulphate — сульфат (на данном производстве сульфид натрия);
#  * Depressant — депрессант (силикат натрия).
#
# Rougher process (англ. «грубый процесс») — флотация\
# Rougher tails — отвальные хвосты\
# Float banks — флотационная установка\
# Cleaner process — очистка\
# Rougher Au — черновой концентрат золота\
# Final Au — финальный концентрат золота
#
# **Параметры этапов**
#
# air amount — объём воздуха\
# fluid levels — уровень жидкости\
# feed size — размер гранул сырья\
# feed rate — скорость подачи

# %% [markdown]
# **Наименование признаков:**
#
# rougher — флотация\
# primary_cleaner — первичная очистка\
# secondary_cleaner — вторичная очистка\
# final — финальные характеристики
#
# input — параметры сырья\
# output — параметры продукта\
# state — параметры, характеризующие текущее состояние этапа\
# calculation — расчётные характеристики

# %% [markdown]
# **Эффективность обогащения рассчитывается по формуле**
#
# Recovery = (C * (F - T)) / (F * (C - T))  * 100 %,
#
# где:
# * C — доля золота в концентрате после флотации/очистки;
# * F — доля золота в сырье/концентрате до флотации/очистки;
# * T — доля золота в отвальных хвостах после флотации/очистки.

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# Импортируем необходимые библиотеки

# %%
import pandas as pd
pd.set_option('display.max_rows', None)
import numpy as np
from sklearn.metrics import mean_absolute_error
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import make_scorer
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.dummy import DummyRegressor
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# Сохраним необходимые данные в таблицах

# %%
gold_train = pd.read_csv('https://code.s3.yandex.net/datasets/gold_recovery_train_new.csv')
gold_test = pd.read_csv('https://code.s3.yandex.net/datasets/gold_recovery_test_new.csv')
gold_full = pd.read_csv('https://code.s3.yandex.net/datasets/gold_recovery_full_new.csv')

# %% [markdown]
# Проверим общую информацию о данных в таблицах

# %%
gold_train.head()
# Out:
#                   date  final.output.concentrate_ag  \
# 0  2016-01-15 00:00:00                     6.055403
# 1  2016-01-15 01:00:00                     6.029369
# 2  2016-01-15 02:00:00                     6.055926
# 3  2016-01-15 03:00:00                     6.047977
# 4  2016-01-15 04:00:00                     6.148599
#
#    final.output.concentrate_pb  final.output.concentrate_sol  \
# 0                     9.889648                      5.507324
# 1                     9.968944                      5.257781
# 2                    10.213995                      5.383759
# 3                     9.977019                      4.858634
# 4                    10.142511                      4.939416
#
#    final.output.concentrate_au  final.output.recovery  final.output.tail_ag  \
# 0                    42.192020              70.541216             10.411962
# 1                    42.701629              69.266198             10.462676
# 2                    42.657501              68.116445             10.507046
# 3                    42.689819              68.347543             10.422762
# 4                    42.774141              66.927016             10.360302
#
#    final.output.tail_pb  final.output.tail_sol  final.output.tail_au  ...  \
# 0              0.895447              16.904297              2.143149  ...
# 1              0.927452              16.634514              2.224930  ...
# 2              0.953716              16.208849              2.257889  ...
# 3              0.883763              16.532835              2.146849  ...
# 4              0.792826              16.525686              2.055292  ...
#
#    secondary_cleaner.state.floatbank4_a_air  \
# 0                                 14.016835
# 1                                 13.992281
# 2                                 14.015015
# 3                                 14.036510
# 4                                 14.027298
#
#    secondary_cleaner.state.floatbank4_a_level  \
# 0                                 -502.488007
# 1                                 -505.503262
# 2                                 -502.520901
# 3                                 -500.857308
# 4                                 -499.838632
#
#    secondary_cleaner.state.floatbank4_b_air  \
# 0                                 12.099931
# 1                                 11.950531
# 2                                 11.912783
# 3                                 11.999550
# 4                                 11.953070
#
#    secondary_cleaner.state.floatbank4_b_level  \
# 0                                 -504.715942
# 1                                 -501.331529
# 2                                 -501.133383
# 3                                 -501.193686
# 4                                 -501.053894
#
#    secondary_cleaner.state.floatbank5_a_air  \
# 0                                  9.925633
# 1                                 10.039245
# 2                                 10.070913
# 3                                  9.970366
# 4                                  9.925709
#
#    secondary_cleaner.state.floatbank5_a_level  \
# 0                                 -498.310211
# 1                                 -500.169983
# 2                                 -500.129135
# 3                                 -499.201640
# 4                                 -501.686727
#
#    secondary_cleaner.state.floatbank5_b_air  \
# 0                                  8.079666
# 1                                  7.984757
# 2                                  8.013877
# 3                                  7.977324
# 4                                  7.894242
#
#    secondary_cleaner.state.floatbank5_b_level  \
# 0                                 -500.470978
# 1                                 -500.582168
# 2                                 -500.517572
# 3                                 -500.255908
# 4                                 -500.356035
#
#    secondary_cleaner.state.floatbank6_a_air  \
# 0                                 14.151341
# 1                                 13.998353
# 2                                 14.028663
# 3                                 14.005551
# 4                                 13.996647
#
#    secondary_cleaner.state.floatbank6_a_level
# 0                                 -605.841980
# 1                                 -599.787184
# 2                                 -601.427363
# 3                                 -599.996129
# 4                                 -601.496691
#
# [5 rows x 87 columns]

# %%
gold_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14149 entries, 0 to 14148
# Data columns (total 87 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                14149 non-null  object
#  1   final.output.concentrate_ag                         14148 non-null  float64
#  2   final.output.concentrate_pb                         14148 non-null  float64
#  3   final.output.concentrate_sol                        13938 non-null  float64
#  4   final.output.concentrate_au                         14149 non-null  float64
#  5   final.output.recovery                               14149 non-null  float64
#  6   final.output.tail_ag                                14149 non-null  float64
#  7   final.output.tail_pb                                14049 non-null  float64
#  8   final.output.tail_sol                               14144 non-null  float64
#  9   final.output.tail_au                                14149 non-null  float64
#  10  primary_cleaner.input.sulfate                       14129 non-null  float64
#  11  primary_cleaner.input.depressant                    14117 non-null  float64
#  12  primary_cleaner.input.feed_size                     14149 non-null  float64
#  13  primary_cleaner.input.xanthate                      14049 non-null  float64
#  14  primary_cleaner.output.concentrate_ag               14149 non-null  float64
#  15  primary_cleaner.output.concentrate_pb               14063 non-null  float64
#  16  primary_cleaner.output.concentrate_sol              13863 non-null  float64
#  17  primary_cleaner.output.concentrate_au               14149 non-null  float64
#  18  primary_cleaner.output.tail_ag                      14148 non-null  float64
#  19  primary_cleaner.output.tail_pb                      14134 non-null  float64
#  20  primary_cleaner.output.tail_sol                     14103 non-null  float64
#  21  primary_cleaner.output.tail_au                      14149 non-null  float64
#  22  primary_cleaner.state.floatbank8_a_air              14145 non-null  float64
#  23  primary_cleaner.state.floatbank8_a_level            14148 non-null  float64
#  24  primary_cleaner.state.floatbank8_b_air              14145 non-null  float64
#  25  primary_cleaner.state.floatbank8_b_level            14148 non-null  float64
#  26  primary_cleaner.state.floatbank8_c_air              14147 non-null  float64
#  27  primary_cleaner.state.floatbank8_c_level            14148 non-null  float64
#  28  primary_cleaner.state.floatbank8_d_air              14146 non-null  float64
#  29  primary_cleaner.state.floatbank8_d_level            14148 non-null  float64
#  30  rougher.calculation.sulfate_to_au_concentrate       14148 non-null  float64
#  31  rougher.calculation.floatbank10_sulfate_to_au_feed  14148 non-null  float64
#  32  rougher.calculation.floatbank11_sulfate_to_au_feed  14148 non-null  float64
#  33  rougher.calculation.au_pb_ratio                     14149 non-null  float64
#  34  rougher.input.feed_ag                               14149 non-null  float64
#  35  rougher.input.feed_pb                               14049 non-null  float64
#  36  rougher.input.feed_rate                             14141 non-null  float64
#  37  rougher.input.feed_size                             14005 non-null  float64
#  38  rougher.input.feed_sol                              14071 non-null  float64
#  39  rougher.input.feed_au                               14149 non-null  float64
#  40  rougher.input.floatbank10_sulfate                   14120 non-null  float64
#  41  rougher.input.floatbank10_xanthate                  14141 non-null  float64
#  42  rougher.input.floatbank11_sulfate                   14113 non-null  float64
#  43  rougher.input.floatbank11_xanthate                  13721 non-null  float64
#  44  rougher.output.concentrate_ag                       14149 non-null  float64
#  45  rougher.output.concentrate_pb                       14149 non-null  float64
#  46  rougher.output.concentrate_sol                      14127 non-null  float64
#  47  rougher.output.concentrate_au                       14149 non-null  float64
#  48  rougher.output.recovery                             14149 non-null  float64
#  49  rougher.output.tail_ag                              14148 non-null  float64
#  50  rougher.output.tail_pb                              14149 non-null  float64
#  51  rougher.output.tail_sol                             14149 non-null  float64
#  52  rougher.output.tail_au                              14149 non-null  float64
#  53  rougher.state.floatbank10_a_air                     14148 non-null  float64
#  54  rougher.state.floatbank10_a_level                   14148 non-null  float64
#  55  rougher.state.floatbank10_b_air                     14148 non-null  float64
#  56  rougher.state.floatbank10_b_level                   14148 non-null  float64
#  57  rougher.state.floatbank10_c_air                     14148 non-null  float64
#  58  rougher.state.floatbank10_c_level                   14148 non-null  float64
#  59  rougher.state.floatbank10_d_air                     14149 non-null  float64
#  60  rougher.state.floatbank10_d_level                   14149 non-null  float64
#  61  rougher.state.floatbank10_e_air                     13713 non-null  float64
#  62  rougher.state.floatbank10_e_level                   14149 non-null  float64
#  63  rougher.state.floatbank10_f_air                     14149 non-null  float64
#  64  rougher.state.floatbank10_f_level                   14149 non-null  float64
#  65  secondary_cleaner.output.tail_ag                    14147 non-null  float64
#  66  secondary_cleaner.output.tail_pb                    14139 non-null  float64
#  67  secondary_cleaner.output.tail_sol                   12544 non-null  float64
#  68  secondary_cleaner.output.tail_au                    14149 non-null  float64
#  69  secondary_cleaner.state.floatbank2_a_air            13932 non-null  float64
#  70  secondary_cleaner.state.floatbank2_a_level          14148 non-null  float64
#  71  secondary_cleaner.state.floatbank2_b_air            14128 non-null  float64
#  72  secondary_cleaner.state.floatbank2_b_level          14148 non-null  float64
#  73  secondary_cleaner.state.floatbank3_a_air            14145 non-null  float64
#  74  secondary_cleaner.state.floatbank3_a_level          14148 non-null  float64
#  75  secondary_cleaner.state.floatbank3_b_air            14148 non-null  float64
#  76  secondary_cleaner.state.floatbank3_b_level          14148 non-null  float64
#  77  secondary_cleaner.state.floatbank4_a_air            14143 non-null  float64
#  78  secondary_cleaner.state.floatbank4_a_level          14148 non-null  float64
#  79  secondary_cleaner.state.floatbank4_b_air            14148 non-null  float64
#  80  secondary_cleaner.state.floatbank4_b_level          14148 non-null  float64
#  81  secondary_cleaner.state.floatbank5_a_air            14148 non-null  float64
#  82  secondary_cleaner.state.floatbank5_a_level          14148 non-null  float64
#  83  secondary_cleaner.state.floatbank5_b_air            14148 non-null  float64
#  84  secondary_cleaner.state.floatbank5_b_level          14148 non-null  float64
#  85  secondary_cleaner.state.floatbank6_a_air            14147 non-null  float64
#  86  secondary_cleaner.state.floatbank6_a_level          14148 non-null  float64
# dtypes: float64(86), object(1)
# memory usage: 9.4+ MB

# %%
gold_test.head()
# Out:
#                   date  primary_cleaner.input.sulfate  \
# 0  2016-09-01 00:59:59                     210.800909
# 1  2016-09-01 01:59:59                     215.392455
# 2  2016-09-01 02:59:59                     215.259946
# 3  2016-09-01 03:59:59                     215.336236
# 4  2016-09-01 04:59:59                     199.099327
#
#    primary_cleaner.input.depressant  primary_cleaner.input.feed_size  \
# 0                         14.993118                         8.080000
# 1                         14.987471                         8.080000
# 2                         12.884934                         7.786667
# 3                         12.006805                         7.640000
# 4                         10.682530                         7.530000
#
#    primary_cleaner.input.xanthate  primary_cleaner.state.floatbank8_a_air  \
# 0                        1.005021                             1398.981301
# 1                        0.990469                             1398.777912
# 2                        0.996043                             1398.493666
# 3                        0.863514                             1399.618111
# 4                        0.805575                             1401.268123
#
#    primary_cleaner.state.floatbank8_a_level  \
# 0                               -500.225577
# 1                               -500.057435
# 2                               -500.868360
# 3                               -498.863574
# 4                               -500.808305
#
#    primary_cleaner.state.floatbank8_b_air  \
# 0                             1399.144926
# 1                             1398.055362
# 2                             1398.860436
# 3                             1397.440120
# 4                             1398.128818
#
#    primary_cleaner.state.floatbank8_b_level  \
# 0                               -499.919735
# 1                               -499.778182
# 2                               -499.764529
# 3                               -499.211024
# 4                               -499.504543
#
#    primary_cleaner.state.floatbank8_c_air  ...  \
# 0                             1400.102998  ...
# 1                             1396.151033  ...
# 2                             1398.075709  ...
# 3                             1400.129303  ...
# 4                             1402.172226  ...
#
#    secondary_cleaner.state.floatbank4_a_air  \
# 0                                 12.023554
# 1                                 12.058140
# 2                                 11.962366
# 3                                 12.033091
# 4                                 12.025367
#
#    secondary_cleaner.state.floatbank4_a_level  \
# 0                                 -497.795834
# 1                                 -498.695773
# 2                                 -498.767484
# 3                                 -498.350935
# 4                                 -500.786497
#
#    secondary_cleaner.state.floatbank4_b_air  \
# 0                                  8.016656
# 1                                  8.130979
# 2                                  8.096893
# 3                                  8.074946
# 4                                  8.054678
#
#    secondary_cleaner.state.floatbank4_b_level  \
# 0                                 -501.289139
# 1                                 -499.634209
# 2                                 -500.827423
# 3                                 -499.474407
# 4                                 -500.397500
#
#    secondary_cleaner.state.floatbank5_a_air  \
# 0                                  7.946562
# 1                                  7.958270
# 2                                  8.071056
# 3                                  7.897085
# 4                                  8.107890
#
#    secondary_cleaner.state.floatbank5_a_level  \
# 0                                 -432.317850
# 1                                 -525.839648
# 2                                 -500.801673
# 3                                 -500.868509
# 4                                 -509.526725
#
#    secondary_cleaner.state.floatbank5_b_air  \
# 0                                  4.872511
# 1                                  4.878850
# 2                                  4.905125
# 3                                  4.931400
# 4                                  4.957674
#
#    secondary_cleaner.state.floatbank5_b_level  \
# 0                                 -500.037437
# 1                                 -500.162375
# 2                                 -499.828510
# 3                                 -499.963623
# 4                                 -500.360026
#
#    secondary_cleaner.state.floatbank6_a_air  \
# 0                                 26.705889
# 1                                 25.019940
# 2                                 24.994862
# 3                                 24.948919
# 4                                 25.003331
#
#    secondary_cleaner.state.floatbank6_a_level
# 0                                 -499.709414
# 1                                 -499.819438
# 2                                 -500.622559
# 3                                 -498.709987
# 4                                 -500.856333
#
# [5 rows x 53 columns]

# %%
gold_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5290 entries, 0 to 5289
# Data columns (total 53 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   date                                        5290 non-null   object
#  1   primary_cleaner.input.sulfate               5286 non-null   float64
#  2   primary_cleaner.input.depressant            5285 non-null   float64
#  3   primary_cleaner.input.feed_size             5290 non-null   float64
#  4   primary_cleaner.input.xanthate              5286 non-null   float64
#  5   primary_cleaner.state.floatbank8_a_air      5290 non-null   float64
#  6   primary_cleaner.state.floatbank8_a_level    5290 non-null   float64
#  7   primary_cleaner.state.floatbank8_b_air      5290 non-null   float64
#  8   primary_cleaner.state.floatbank8_b_level    5290 non-null   float64
#  9   primary_cleaner.state.floatbank8_c_air      5290 non-null   float64
#  10  primary_cleaner.state.floatbank8_c_level    5290 non-null   float64
#  11  primary_cleaner.state.floatbank8_d_air      5290 non-null   float64
#  12  primary_cleaner.state.floatbank8_d_level    5290 non-null   float64
#  13  rougher.input.feed_ag                       5290 non-null   float64
#  14  rougher.input.feed_pb                       5290 non-null   float64
#  15  rougher.input.feed_rate                     5287 non-null   float64
#  16  rougher.input.feed_size                     5289 non-null   float64
#  17  rougher.input.feed_sol                      5269 non-null   float64
#  18  rougher.input.feed_au                       5290 non-null   float64
#  19  rougher.input.floatbank10_sulfate           5285 non-null   float64
#  20  rougher.input.floatbank10_xanthate          5290 non-null   float64
#  21  rougher.input.floatbank11_sulfate           5282 non-null   float64
#  22  rougher.input.floatbank11_xanthate          5265 non-null   float64
#  23  rougher.state.floatbank10_a_air             5290 non-null   float64
#  24  rougher.state.floatbank10_a_level           5290 non-null   float64
#  25  rougher.state.floatbank10_b_air             5290 non-null   float64
#  26  rougher.state.floatbank10_b_level           5290 non-null   float64
#  27  rougher.state.floatbank10_c_air             5290 non-null   float64
#  28  rougher.state.floatbank10_c_level           5290 non-null   float64
#  29  rougher.state.floatbank10_d_air             5290 non-null   float64
#  30  rougher.state.floatbank10_d_level           5290 non-null   float64
#  31  rougher.state.floatbank10_e_air             5290 non-null   float64
#  32  rougher.state.floatbank10_e_level           5290 non-null   float64
#  33  rougher.state.floatbank10_f_air             5290 non-null   float64
#  34  rougher.state.floatbank10_f_level           5290 non-null   float64
#  35  secondary_cleaner.state.floatbank2_a_air    5287 non-null   float64
#  36  secondary_cleaner.state.floatbank2_a_level  5290 non-null   float64
#  37  secondary_cleaner.state.floatbank2_b_air    5288 non-null   float64
#  38  secondary_cleaner.state.floatbank2_b_level  5290 non-null   float64
#  39  secondary_cleaner.state.floatbank3_a_air    5281 non-null   float64
#  40  secondary_cleaner.state.floatbank3_a_level  5290 non-null   float64
#  41  secondary_cleaner.state.floatbank3_b_air    5290 non-null   float64
#  42  secondary_cleaner.state.floatbank3_b_level  5290 non-null   float64
#  43  secondary_cleaner.state.floatbank4_a_air    5290 non-null   float64
#  44  secondary_cleaner.state.floatbank4_a_level  5290 non-null   float64
#  45  secondary_cleaner.state.floatbank4_b_air    5290 non-null   float64
#  46  secondary_cleaner.state.floatbank4_b_level  5290 non-null   float64
#  47  secondary_cleaner.state.floatbank5_a_air    5290 non-null   float64
#  48  secondary_cleaner.state.floatbank5_a_level  5290 non-null   float64
#  49  secondary_cleaner.state.floatbank5_b_air    5290 non-null   float64
#  50  secondary_cleaner.state.floatbank5_b_level  5290 non-null   float64
#  51  secondary_cleaner.state.floatbank6_a_air    5290 non-null   float64
#  52  secondary_cleaner.state.floatbank6_a_level  5290 non-null   float64
# dtypes: float64(52), object(1)
# memory usage: 2.1+ MB

# %%
gold_full.head()
# Out:
#                   date  final.output.concentrate_ag  \
# 0  2016-01-15 00:00:00                     6.055403
# 1  2016-01-15 01:00:00                     6.029369
# 2  2016-01-15 02:00:00                     6.055926
# 3  2016-01-15 03:00:00                     6.047977
# 4  2016-01-15 04:00:00                     6.148599
#
#    final.output.concentrate_pb  final.output.concentrate_sol  \
# 0                     9.889648                      5.507324
# 1                     9.968944                      5.257781
# 2                    10.213995                      5.383759
# 3                     9.977019                      4.858634
# 4                    10.142511                      4.939416
#
#    final.output.concentrate_au  final.output.recovery  final.output.tail_ag  \
# 0                    42.192020              70.541216             10.411962
# 1                    42.701629              69.266198             10.462676
# 2                    42.657501              68.116445             10.507046
# 3                    42.689819              68.347543             10.422762
# 4                    42.774141              66.927016             10.360302
#
#    final.output.tail_pb  final.output.tail_sol  final.output.tail_au  ...  \
# 0              0.895447              16.904297              2.143149  ...
# 1              0.927452              16.634514              2.224930  ...
# 2              0.953716              16.208849              2.257889  ...
# 3              0.883763              16.532835              2.146849  ...
# 4              0.792826              16.525686              2.055292  ...
#
#    secondary_cleaner.state.floatbank4_a_air  \
# 0                                 14.016835
# 1                                 13.992281
# 2                                 14.015015
# 3                                 14.036510
# 4                                 14.027298
#
#    secondary_cleaner.state.floatbank4_a_level  \
# 0                                 -502.488007
# 1                                 -505.503262
# 2                                 -502.520901
# 3                                 -500.857308
# 4                                 -499.838632
#
#    secondary_cleaner.state.floatbank4_b_air  \
# 0                                 12.099931
# 1                                 11.950531
# 2                                 11.912783
# 3                                 11.999550
# 4                                 11.953070
#
#    secondary_cleaner.state.floatbank4_b_level  \
# 0                                 -504.715942
# 1                                 -501.331529
# 2                                 -501.133383
# 3                                 -501.193686
# 4                                 -501.053894
#
#    secondary_cleaner.state.floatbank5_a_air  \
# 0                                  9.925633
# 1                                 10.039245
# 2                                 10.070913
# 3                                  9.970366
# 4                                  9.925709
#
#    secondary_cleaner.state.floatbank5_a_level  \
# 0                                 -498.310211
# 1                                 -500.169983
# 2                                 -500.129135
# 3                                 -499.201640
# 4                                 -501.686727
#
#    secondary_cleaner.state.floatbank5_b_air  \
# 0                                  8.079666
# 1                                  7.984757
# 2                                  8.013877
# 3                                  7.977324
# 4                                  7.894242
#
#    secondary_cleaner.state.floatbank5_b_level  \
# 0                                 -500.470978
# 1                                 -500.582168
# 2                                 -500.517572
# 3                                 -500.255908
# 4                                 -500.356035
#
#    secondary_cleaner.state.floatbank6_a_air  \
# 0                                 14.151341
# 1                                 13.998353
# 2                                 14.028663
# 3                                 14.005551
# 4                                 13.996647
#
#    secondary_cleaner.state.floatbank6_a_level
# 0                                 -605.841980
# 1                                 -599.787184
# 2                                 -601.427363
# 3                                 -599.996129
# 4                                 -601.496691
#
# [5 rows x 87 columns]

# %%
gold_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19439 entries, 0 to 19438
# Data columns (total 87 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                19439 non-null  object
#  1   final.output.concentrate_ag                         19438 non-null  float64
#  2   final.output.concentrate_pb                         19438 non-null  float64
#  3   final.output.concentrate_sol                        19228 non-null  float64
#  4   final.output.concentrate_au                         19439 non-null  float64
#  5   final.output.recovery                               19439 non-null  float64
#  6   final.output.tail_ag                                19438 non-null  float64
#  7   final.output.tail_pb                                19338 non-null  float64
#  8   final.output.tail_sol                               19433 non-null  float64
#  9   final.output.tail_au                                19439 non-null  float64
#  10  primary_cleaner.input.sulfate                       19415 non-null  float64
#  11  primary_cleaner.input.depressant                    19402 non-null  float64
#  12  primary_cleaner.input.feed_size                     19439 non-null  float64
#  13  primary_cleaner.input.xanthate                      19335 non-null  float64
#  14  primary_cleaner.output.concentrate_ag               19439 non-null  float64
#  15  primary_cleaner.output.concentrate_pb               19323 non-null  float64
#  16  primary_cleaner.output.concentrate_sol              19069 non-null  float64
#  17  primary_cleaner.output.concentrate_au               19439 non-null  float64
#  18  primary_cleaner.output.tail_ag                      19435 non-null  float64
#  19  primary_cleaner.output.tail_pb                      19418 non-null  float64
#  20  primary_cleaner.output.tail_sol                     19377 non-null  float64
#  21  primary_cleaner.output.tail_au                      19439 non-null  float64
#  22  primary_cleaner.state.floatbank8_a_air              19435 non-null  float64
#  23  primary_cleaner.state.floatbank8_a_level            19438 non-null  float64
#  24  primary_cleaner.state.floatbank8_b_air              19435 non-null  float64
#  25  primary_cleaner.state.floatbank8_b_level            19438 non-null  float64
#  26  primary_cleaner.state.floatbank8_c_air              19437 non-null  float64
#  27  primary_cleaner.state.floatbank8_c_level            19438 non-null  float64
#  28  primary_cleaner.state.floatbank8_d_air              19436 non-null  float64
#  29  primary_cleaner.state.floatbank8_d_level            19438 non-null  float64
#  30  rougher.calculation.sulfate_to_au_concentrate       19437 non-null  float64
#  31  rougher.calculation.floatbank10_sulfate_to_au_feed  19437 non-null  float64
#  32  rougher.calculation.floatbank11_sulfate_to_au_feed  19437 non-null  float64
#  33  rougher.calculation.au_pb_ratio                     19439 non-null  float64
#  34  rougher.input.feed_ag                               19439 non-null  float64
#  35  rougher.input.feed_pb                               19339 non-null  float64
#  36  rougher.input.feed_rate                             19428 non-null  float64
#  37  rougher.input.feed_size                             19294 non-null  float64
#  38  rougher.input.feed_sol                              19340 non-null  float64
#  39  rougher.input.feed_au                               19439 non-null  float64
#  40  rougher.input.floatbank10_sulfate                   19405 non-null  float64
#  41  rougher.input.floatbank10_xanthate                  19431 non-null  float64
#  42  rougher.input.floatbank11_sulfate                   19395 non-null  float64
#  43  rougher.input.floatbank11_xanthate                  18986 non-null  float64
#  44  rougher.output.concentrate_ag                       19439 non-null  float64
#  45  rougher.output.concentrate_pb                       19439 non-null  float64
#  46  rougher.output.concentrate_sol                      19416 non-null  float64
#  47  rougher.output.concentrate_au                       19439 non-null  float64
#  48  rougher.output.recovery                             19439 non-null  float64
#  49  rougher.output.tail_ag                              19438 non-null  float64
#  50  rougher.output.tail_pb                              19439 non-null  float64
#  51  rougher.output.tail_sol                             19439 non-null  float64
#  52  rougher.output.tail_au                              19439 non-null  float64
#  53  rougher.state.floatbank10_a_air                     19438 non-null  float64
#  54  rougher.state.floatbank10_a_level                   19438 non-null  float64
#  55  rougher.state.floatbank10_b_air                     19438 non-null  float64
#  56  rougher.state.floatbank10_b_level                   19438 non-null  float64
#  57  rougher.state.floatbank10_c_air                     19438 non-null  float64
#  58  rougher.state.floatbank10_c_level                   19438 non-null  float64
#  59  rougher.state.floatbank10_d_air                     19439 non-null  float64
#  60  rougher.state.floatbank10_d_level                   19439 non-null  float64
#  61  rougher.state.floatbank10_e_air                     19003 non-null  float64
#  62  rougher.state.floatbank10_e_level                   19439 non-null  float64
#  63  rougher.state.floatbank10_f_air                     19439 non-null  float64
#  64  rougher.state.floatbank10_f_level                   19439 non-null  float64
#  65  secondary_cleaner.output.tail_ag                    19437 non-null  float64
#  66  secondary_cleaner.output.tail_pb                    19427 non-null  float64
#  67  secondary_cleaner.output.tail_sol                   17691 non-null  float64
#  68  secondary_cleaner.output.tail_au                    19439 non-null  float64
#  69  secondary_cleaner.state.floatbank2_a_air            19219 non-null  float64
#  70  secondary_cleaner.state.floatbank2_a_level          19438 non-null  float64
#  71  secondary_cleaner.state.floatbank2_b_air            19416 non-null  float64
#  72  secondary_cleaner.state.floatbank2_b_level          19438 non-null  float64
#  73  secondary_cleaner.state.floatbank3_a_air            19426 non-null  float64
#  74  secondary_cleaner.state.floatbank3_a_level          19438 non-null  float64
#  75  secondary_cleaner.state.floatbank3_b_air            19438 non-null  float64
#  76  secondary_cleaner.state.floatbank3_b_level          19438 non-null  float64
#  77  secondary_cleaner.state.floatbank4_a_air            19433 non-null  float64
#  78  secondary_cleaner.state.floatbank4_a_level          19438 non-null  float64
#  79  secondary_cleaner.state.floatbank4_b_air            19438 non-null  float64
#  80  secondary_cleaner.state.floatbank4_b_level          19438 non-null  float64
#  81  secondary_cleaner.state.floatbank5_a_air            19438 non-null  float64
#  82  secondary_cleaner.state.floatbank5_a_level          19438 non-null  float64
#  83  secondary_cleaner.state.floatbank5_b_air            19438 non-null  float64
#  84  secondary_cleaner.state.floatbank5_b_level          19438 non-null  float64
#  85  secondary_cleaner.state.floatbank6_a_air            19437 non-null  float64
#  86  secondary_cleaner.state.floatbank6_a_level          19438 non-null  float64
# dtypes: float64(86), object(1)
# memory usage: 12.9+ MB

# %% [markdown]
# 1) Первый столбец всех таблиц имеет формат object, хотя содержит дату и время, его можно перевести в формат datetime\
# 2) В таблице gold_test меньше столбцов, чем в остальных таблицах (53 вместо 87)\
# 3) В таблицах есть пропуски значений

# %% [markdown]
# **Проверим, что эффективность обогащения рассчитана правильно. Вычислим её на обучающей выборке для признака `rougher.output.recovery`**

# %%
def recovery(C,F,T):
    recovery = (C * (F - T)) / (F * (C - T)) * 100
    return recovery

# %%
rougher_recovery = recovery(gold_train['rougher.output.concentrate_au'], 
                            gold_train['rougher.input.feed_au'], 
                            gold_train['rougher.output.tail_au'])

# %%
rougher_recovery.head()
# Out:
# 0    87.107763
# 1    86.843261
# 2    86.842308
# 3    87.226430
# 4    86.688794
# dtype: float64

# %%
gold_train['rougher.output.recovery'].head()
# Out:
# 0    87.107763
# 1    86.843261
# 2    86.842308
# 3    87.226430
# 4    86.688794
# Name: rougher.output.recovery, dtype: float64

# %% [markdown]
# Найдём MAE между нашими расчётами и значением признака

# %%
mean_absolute_error(gold_train['rougher.output.recovery'], rougher_recovery)
# Out:
# 9.73512347450521e-15

# %% [markdown]
# Значения в столбце rougher.output.recovery совпадают, что может свидетельствовать о том, что величина в столбце `rougher.output.recovery` раситывается по той же формуле, на основе данных в столбцах `rougher.output.concentrate_au`, `rougher.input.feed_au` и `rougher.output.tail_au`

# %% [markdown]
# **Проанализируем признаки, недоступные в тестовой выборке**

# %%
dif_tables = gold_full.columns.difference(gold_test.columns)
print('Cтолбцы, отсутствующие в тестовой выборке:','\n', dif_tables)
print('Количество столбцов, отсутствующих в тестовой выборке:', len(dif_tables))
# Out:
# Cтолбцы, отсутствующие в тестовой выборке:
#  Index(['final.output.concentrate_ag', 'final.output.concentrate_au',
#        'final.output.concentrate_pb', 'final.output.concentrate_sol',
#        'final.output.recovery', 'final.output.tail_ag', 'final.output.tail_au',
#        'final.output.tail_pb', 'final.output.tail_sol',
#        'primary_cleaner.output.concentrate_ag',
#        'primary_cleaner.output.concentrate_au',
#        'primary_cleaner.output.concentrate_pb',
#        'primary_cleaner.output.concentrate_sol',
#        'primary_cleaner.output.tail_ag', 'primary_cleaner.output.tail_au',
#        'primary_cleaner.output.tail_pb', 'primary_cleaner.output.tail_sol',
#        'rougher.calculation.au_pb_ratio',
#        'rougher.calculation.floatbank10_sulfate_to_au_feed',
#        'rougher.calculation.floatbank11_sulfate_to_au_feed',
#        'rougher.calculation.sulfate_to_au_concentrate',
#        'rougher.output.concentrate_ag', 'rougher.output.concentrate_au',
#        'rougher.output.concentrate_pb', 'rougher.output.concentrate_sol',
#        'rougher.output.recovery', 'rougher.output.tail_ag',
#        'rougher.output.tail_au', 'rougher.output.tail_pb',
#        'rougher.output.tail_sol', 'secondary_cleaner.output.tail_ag',
#        'secondary_cleaner.output.tail_au', 'secondary_cleaner.output.tail_pb',
#        'secondary_cleaner.output.tail_sol'],
#       dtype='object')
# Количество столбцов, отсутствующих в тестовой выборке: 34

# %% [markdown]
# 1) В тестовой выборке отсутствуют значения параметров продукта (выходные значения) для всех этапов технологического процесса (флотация, первичная очистка, вторичная очистка, финальные характеристики).
#
# 2) В тестовой выборке нет параметров `feed`, необходимых для проверки размеров гранул сырья.

# %% [markdown]
# Дополним тестовую выборку недостающими столбцами из полной выборки

# %%
gold_test = gold_test.merge(gold_full, how = 'left')
gold_test.shape
# Out:
# (5290, 87)

# %% [markdown]
# **Проверим долю пропущенных значений от общего количества значений в процентах**

# %%
gold_full.isna().mean().sort_values(ascending=False).head(20)*100
# Out:
# secondary_cleaner.output.tail_sol           8.992232
# rougher.input.floatbank11_xanthate          2.330367
# rougher.state.floatbank10_e_air             2.242914
# primary_cleaner.output.concentrate_sol      1.903390
# secondary_cleaner.state.floatbank2_a_air    1.131745
# final.output.concentrate_sol                1.085447
# rougher.input.feed_size                     0.745923
# primary_cleaner.output.concentrate_pb       0.596739
# primary_cleaner.input.xanthate              0.535007
# final.output.tail_pb                        0.519574
# rougher.input.feed_pb                       0.514430
# rougher.input.feed_sol                      0.509285
# primary_cleaner.output.tail_sol             0.318946
# rougher.input.floatbank11_sulfate           0.226349
# primary_cleaner.input.depressant            0.190339
# rougher.input.floatbank10_sulfate           0.174906
# primary_cleaner.input.sulfate               0.123463
# rougher.output.concentrate_sol              0.118319
# secondary_cleaner.state.floatbank2_b_air    0.118319
# primary_cleaner.output.tail_pb              0.108030
# dtype: float64

# %% [markdown]
# Доля пропущенных значений не превышает 10%, рассмотрим подробнее первые три параметра с долей пропусков более 2%, так как доля пропусков в остальных параметрах не превышает 2%, то удалим их.

# %%
gold_full['secondary_cleaner.output.tail_sol'].hist(bins=30, figsize=(16,9));

# %%
gold_full['secondary_cleaner.output.tail_sol'].describe()
# Out:
# count    17691.000000
# mean         7.167247
# std          3.916079
# min          0.000000
# 25%          3.845475
# 50%          7.685827
# 75%         10.411296
# max         26.000772
# Name: secondary_cleaner.output.tail_sol, dtype: float64

# %% [markdown]
# Из-за большого количества нулевых значений среднее смещено ближе к нулю, заполним пропуски медианными значениями

# %%
gold_full['secondary_cleaner.output.tail_sol'] = (
gold_full['secondary_cleaner.output.tail_sol'].fillna(gold_full['secondary_cleaner.output.tail_sol'].median()))

# %% [markdown]
# Распределение не похоже на "нормальное", есть много нулевых значений параметра

# %%
gold_full['rougher.input.floatbank11_xanthate'].hist(bins=30, figsize=(16,9));

# %%
gold_full['rougher.input.floatbank11_xanthate'] = (
gold_full['rougher.input.floatbank11_xanthate'].fillna(gold_full['rougher.input.floatbank11_xanthate'].mean()))

# %% [markdown]
# Распределение похоже на нормальное и пропуски можно заменить на средние значения

# %%
gold_full['rougher.state.floatbank10_e_air'].hist(bins=30, figsize=(16,9));

# %% [markdown]
# Распределение похоже на нормальное и пропуски можно заменить на средние значения

# %%
gold_full['rougher.state.floatbank10_e_air'] = (
gold_full['rougher.state.floatbank10_e_air'].fillna(gold_full['rougher.state.floatbank10_e_air'].mean()))

# %% [markdown]
# Проверим, сколько информации мы потеряем в случае удаления оставшихся строк с пропусками

# %%
gold_full.dropna().shape
# Out:
# (18164, 87)

# %% [markdown]
# Останется 18164 строки из исходных 19434, суммарные потери не превысят 7%, удалим строки с оставшимися пропущенными значениями.

# %%
gold_full = gold_full.dropna()

# %% [markdown]
# Создадим функцию для заполнения пропусков в обучающей и тестовой выборках

# %%
def filling(df):
    df['secondary_cleaner.output.tail_sol'] = (
    df['secondary_cleaner.output.tail_sol'].fillna(df['secondary_cleaner.output.tail_sol'].median()))
    df['rougher.input.floatbank11_xanthate'] = (
    df['rougher.input.floatbank11_xanthate'].fillna(df['rougher.input.floatbank11_xanthate'].mean()))
    df['rougher.state.floatbank10_e_air'] = (
    df['rougher.state.floatbank10_e_air'].fillna(df['rougher.state.floatbank10_e_air'].mean()))
    df = df.dropna()
    return df

# %%
gold_test = filling(gold_test)

# %%
gold_train = filling(gold_train)

# %% [markdown]
# **Проверим наличие выбросов и анамалий**

# %%
gold_full.describe().T
# Out:
#                                                       count          mean  \
# final.output.concentrate_ag                         18164.0      5.160709
# final.output.concentrate_pb                         18164.0     10.021711
# final.output.concentrate_sol                        18164.0      9.614035
# final.output.concentrate_au                         18164.0     44.342318
# final.output.recovery                               18164.0     67.700800
# final.output.tail_ag                                18164.0      9.766414
# final.output.tail_pb                                18164.0      2.733293
# final.output.tail_sol                               18164.0     10.652980
# final.output.tail_au                                18164.0      3.059904
# primary_cleaner.input.sulfate                       18164.0    148.535291
# primary_cleaner.input.depressant                    18164.0      8.975936
# primary_cleaner.input.feed_size                     18164.0      7.317177
# primary_cleaner.input.xanthate                      18164.0      1.038576
# primary_cleaner.output.concentrate_ag               18164.0      8.541476
# primary_cleaner.output.concentrate_pb               18164.0      9.944044
# primary_cleaner.output.concentrate_sol              18164.0     10.554896
# primary_cleaner.output.concentrate_au               18164.0     32.117867
# primary_cleaner.output.tail_ag                      18164.0     16.202679
# primary_cleaner.output.tail_pb                      18164.0      3.463051
# primary_cleaner.output.tail_sol                     18164.0      8.064734
# primary_cleaner.output.tail_au                      18164.0      3.886339
# primary_cleaner.state.floatbank8_a_air              18164.0   1588.765061
# primary_cleaner.state.floatbank8_a_level            18164.0   -491.353219
# primary_cleaner.state.floatbank8_b_air              18164.0   1591.646957
# primary_cleaner.state.floatbank8_b_level            18164.0   -492.352312
# primary_cleaner.state.floatbank8_c_air              18164.0   1586.784601
# primary_cleaner.state.floatbank8_c_level            18164.0   -492.102869
# primary_cleaner.state.floatbank8_d_air              18164.0   1551.414661
# primary_cleaner.state.floatbank8_d_level            18164.0   -488.703544
# rougher.calculation.sulfate_to_au_concentrate       18164.0  41861.492137
# rougher.calculation.floatbank10_sulfate_to_au_feed  18164.0   3345.674235
# rougher.calculation.floatbank11_sulfate_to_au_feed  18164.0   3215.437699
# rougher.calculation.au_pb_ratio                     18164.0      2.428465
# rougher.input.feed_ag                               18164.0      8.881569
# rougher.input.feed_pb                               18164.0      3.634480
# rougher.input.feed_rate                             18164.0    482.654079
# rougher.input.feed_size                             18164.0     58.468476
# rougher.input.feed_sol                              18164.0     36.925624
# rougher.input.feed_au                               18164.0      8.395574
# rougher.input.floatbank10_sulfate                   18164.0     12.524602
# rougher.input.floatbank10_xanthate                  18164.0      6.096739
# rougher.input.floatbank11_sulfate                   18164.0     12.285593
# rougher.input.floatbank11_xanthate                  18164.0      6.123167
# rougher.output.concentrate_ag                       18164.0     12.036312
# rougher.output.concentrate_pb                       18164.0      7.607875
# rougher.output.concentrate_sol                      18164.0     28.934529
# rougher.output.concentrate_au                       18164.0     19.832956
# rougher.output.recovery                             18164.0     83.739215
# rougher.output.tail_ag                              18164.0      5.606673
# rougher.output.tail_pb                              18164.0      0.644467
# rougher.output.tail_sol                             18164.0     18.068994
# rougher.output.tail_au                              18164.0      1.813808
# rougher.state.floatbank10_a_air                     18164.0   1107.226529
# rougher.state.floatbank10_a_level                   18164.0   -375.791482
# rougher.state.floatbank10_b_air                     18164.0   1316.506736
# rougher.state.floatbank10_b_level                   18164.0   -467.571754
# rougher.state.floatbank10_c_air                     18164.0   1296.184181
# rougher.state.floatbank10_c_level                   18164.0   -468.097295
# rougher.state.floatbank10_d_air                     18164.0   1206.046406
# rougher.state.floatbank10_d_level                   18164.0   -468.504782
# rougher.state.floatbank10_e_air                     18164.0   1075.428408
# rougher.state.floatbank10_e_level                   18164.0   -466.337888
# rougher.state.floatbank10_f_air                     18164.0   1020.264494
# rougher.state.floatbank10_f_level                   18164.0   -466.307207
# secondary_cleaner.output.tail_ag                    18164.0     14.656572
# secondary_cleaner.output.tail_pb                    18164.0      5.789204
# secondary_cleaner.output.tail_sol                   18164.0      7.243780
# secondary_cleaner.output.tail_au                    18164.0      4.312568
# secondary_cleaner.state.floatbank2_a_air            18164.0     28.721909
# secondary_cleaner.state.floatbank2_a_level          18164.0   -502.157074
# secondary_cleaner.state.floatbank2_b_air            18164.0     24.074679
# secondary_cleaner.state.floatbank2_b_level          18164.0   -502.771414
# secondary_cleaner.state.floatbank3_a_air            18164.0     28.188900
# secondary_cleaner.state.floatbank3_a_level          18164.0   -486.007123
# secondary_cleaner.state.floatbank3_b_air            18164.0     22.194530
# secondary_cleaner.state.floatbank3_b_level          18164.0   -493.780259
# secondary_cleaner.state.floatbank4_a_air            18164.0     18.931271
# secondary_cleaner.state.floatbank4_a_level          18164.0   -485.724448
# secondary_cleaner.state.floatbank4_b_air            18164.0     14.997153
# secondary_cleaner.state.floatbank4_b_level          18164.0   -461.048463
# secondary_cleaner.state.floatbank5_a_air            18164.0     15.593074
# secondary_cleaner.state.floatbank5_a_level          18164.0   -488.595717
# secondary_cleaner.state.floatbank5_b_air            18164.0     12.088849
# secondary_cleaner.state.floatbank5_b_level          18164.0   -487.183173
# secondary_cleaner.state.floatbank6_a_air            18164.0     18.887126
# secondary_cleaner.state.floatbank6_a_level          18164.0   -505.694474
#
#                                                               std  \
# final.output.concentrate_ag                              1.323115
# final.output.concentrate_pb                              1.566978
# final.output.concentrate_sol                             2.736866
# final.output.concentrate_au                              4.336886
# final.output.recovery                                    8.803021
# final.output.tail_ag                                     2.301415
# final.output.tail_pb                                     0.939153
# final.output.tail_sol                                    2.732250
# final.output.tail_au                                     0.882567
# primary_cleaner.input.sulfate                           41.986893
# primary_cleaner.input.depressant                         3.217708
# primary_cleaner.input.feed_size                          0.597038
# primary_cleaner.input.xanthate                           0.514621
# primary_cleaner.output.concentrate_ag                    1.982242
# primary_cleaner.output.concentrate_pb                    2.436070
# primary_cleaner.output.concentrate_sol                   3.868642
# primary_cleaner.output.concentrate_au                    5.321944
# primary_cleaner.output.tail_ag                           3.517526
# primary_cleaner.output.tail_pb                           1.397853
# primary_cleaner.output.tail_sol                          2.137917
# primary_cleaner.output.tail_au                           1.476240
# primary_cleaner.state.floatbank8_a_air                 125.870936
# primary_cleaner.state.floatbank8_a_level                30.949239
# primary_cleaner.state.floatbank8_b_air                 129.236279
# primary_cleaner.state.floatbank8_b_level                32.250809
# primary_cleaner.state.floatbank8_c_air                 131.928159
# primary_cleaner.state.floatbank8_c_level                30.759028
# primary_cleaner.state.floatbank8_d_air                 235.440503
# primary_cleaner.state.floatbank8_d_level                42.659246
# rougher.calculation.sulfate_to_au_concentrate       335432.314507
# rougher.calculation.floatbank10_sulfate_to_au_feed    4767.575258
# rougher.calculation.floatbank11_sulfate_to_au_feed    5400.229369
# rougher.calculation.au_pb_ratio                          0.702096
# rougher.input.feed_ag                                    1.935184
# rougher.input.feed_pb                                    1.040730
# rougher.input.feed_rate                                 99.694870
# rougher.input.feed_size                                 19.490513
# rougher.input.feed_sol                                   4.880860
# rougher.input.feed_au                                    1.880049
# rougher.input.floatbank10_sulfate                        3.231261
# rougher.input.floatbank10_xanthate                       1.021505
# rougher.input.floatbank11_sulfate                        3.626694
# rougher.input.floatbank11_xanthate                       1.023852
# rougher.output.concentrate_ag                            2.714192
# rougher.output.concentrate_pb                            1.773762
# rougher.output.concentrate_sol                           5.881658
# rougher.output.concentrate_au                            3.724923
# rougher.output.recovery                                 14.008132
# rougher.output.tail_ag                                   1.093447
# rougher.output.tail_pb                                   0.236938
# rougher.output.tail_sol                                  3.298090
# rougher.output.tail_au                                   0.649972
# rougher.state.floatbank10_a_air                        161.572128
# rougher.state.floatbank10_a_level                       93.228246
# rougher.state.floatbank10_b_air                        175.362905
# rougher.state.floatbank10_b_level                       53.997022
# rougher.state.floatbank10_c_air                        202.940718
# rougher.state.floatbank10_c_level                       52.915039
# rougher.state.floatbank10_d_air                        202.653992
# rougher.state.floatbank10_d_level                       53.019096
# rougher.state.floatbank10_e_air                        167.171738
# rougher.state.floatbank10_e_level                       56.954039
# rougher.state.floatbank10_f_air                        161.573422
# rougher.state.floatbank10_f_level                       56.971405
# secondary_cleaner.output.tail_ag                         4.205637
# secondary_cleaner.output.tail_pb                         2.777947
# secondary_cleaner.output.tail_sol                        3.751291
# secondary_cleaner.output.tail_au                         2.225929
# secondary_cleaner.state.floatbank2_a_air                 5.406234
# secondary_cleaner.state.floatbank2_a_level              52.102734
# secondary_cleaner.state.floatbank2_b_air                 5.696803
# secondary_cleaner.state.floatbank2_b_level              55.436650
# secondary_cleaner.state.floatbank3_a_air                 6.067434
# secondary_cleaner.state.floatbank3_a_level              54.224444
# secondary_cleaner.state.floatbank3_b_air                 5.553465
# secondary_cleaner.state.floatbank3_b_level              42.770638
# secondary_cleaner.state.floatbank4_a_air                 5.299026
# secondary_cleaner.state.floatbank4_a_level              47.564257
# secondary_cleaner.state.floatbank4_b_air                 4.852687
# secondary_cleaner.state.floatbank4_b_level              66.750998
# secondary_cleaner.state.floatbank5_a_air                 5.470505
# secondary_cleaner.state.floatbank5_a_level              34.443206
# secondary_cleaner.state.floatbank5_b_air                 5.260604
# secondary_cleaner.state.floatbank5_b_level              38.148158
# secondary_cleaner.state.floatbank6_a_air                 5.547144
# secondary_cleaner.state.floatbank6_a_level              37.412657
#
#                                                              min  \
# final.output.concentrate_ag                         0.000000e+00
# final.output.concentrate_pb                         0.000000e+00
# final.output.concentrate_sol                        0.000000e+00
# final.output.concentrate_au                         0.000000e+00
# final.output.recovery                               0.000000e+00
# final.output.tail_ag                                0.000000e+00
# final.output.tail_pb                                0.000000e+00
# final.output.tail_sol                               0.000000e+00
# final.output.tail_au                                0.000000e+00
# primary_cleaner.input.sulfate                       1.873963e+00
# primary_cleaner.input.depressant                    0.000000e+00
# primary_cleaner.input.feed_size                     1.080000e+00
# primary_cleaner.input.xanthate                      1.543956e-04
# primary_cleaner.output.concentrate_ag               0.000000e+00
# primary_cleaner.output.concentrate_pb               0.000000e+00
# primary_cleaner.output.concentrate_sol              0.000000e+00
# primary_cleaner.output.concentrate_au               0.000000e+00
# primary_cleaner.output.tail_ag                      0.000000e+00
# primary_cleaner.output.tail_pb                      0.000000e+00
# primary_cleaner.output.tail_sol                     0.000000e+00
# primary_cleaner.output.tail_au                      0.000000e+00
# primary_cleaner.state.floatbank8_a_air              1.011533e+03
# primary_cleaner.state.floatbank8_a_level           -6.534776e+02
# primary_cleaner.state.floatbank8_b_air              1.012934e+03
# primary_cleaner.state.floatbank8_b_level           -7.999963e+02
# primary_cleaner.state.floatbank8_c_air              2.735368e+02
# primary_cleaner.state.floatbank8_c_level           -7.907157e+02
# primary_cleaner.state.floatbank8_d_air              5.233482e+02
# primary_cleaner.state.floatbank8_d_level           -7.997916e+02
# rougher.calculation.sulfate_to_au_concentrate      -4.223520e+07
# rougher.calculation.floatbank10_sulfate_to_au_feed -4.865987e+02
# rougher.calculation.floatbank11_sulfate_to_au_feed -2.649828e+02
# rougher.calculation.au_pb_ratio                     9.764530e-01
# rougher.input.feed_ag                               1.000000e-02
# rougher.input.feed_pb                               1.000000e-02
# rougher.input.feed_rate                             2.985849e-03
# rougher.input.feed_size                             4.636880e-02
# rougher.input.feed_sol                              1.000000e-02
# rougher.input.feed_au                               1.000000e-02
# rougher.input.floatbank10_sulfate                   1.147460e-03
# rougher.input.floatbank10_xanthate                  5.682328e-04
# rougher.input.floatbank11_sulfate                   7.673764e-05
# rougher.input.floatbank11_xanthate                  2.904126e-04
# rougher.output.concentrate_ag                       0.000000e+00
# rougher.output.concentrate_pb                       0.000000e+00
# rougher.output.concentrate_sol                      0.000000e+00
# rougher.output.concentrate_au                       0.000000e+00
# rougher.output.recovery                             0.000000e+00
# rougher.output.tail_ag                              2.158369e+00
# rougher.output.tail_pb                              7.566066e-03
# rougher.output.tail_sol                             1.001465e+01
# rougher.output.tail_au                              2.067578e-02
# rougher.state.floatbank10_a_air                     2.991028e+02
# rougher.state.floatbank10_a_level                  -6.569199e+02
# rougher.state.floatbank10_b_air                     3.790231e+02
# rougher.state.floatbank10_b_level                  -5.589676e+02
# rougher.state.floatbank10_c_air                     4.150174e+02
# rougher.state.floatbank10_c_level                  -6.103575e+02
# rougher.state.floatbank10_d_air                     3.040937e+02
# rougher.state.floatbank10_d_level                  -6.483907e+02
# rougher.state.floatbank10_e_air                     9.437202e+01
# rougher.state.floatbank10_e_level                  -6.494439e+02
# rougher.state.floatbank10_f_air                     6.949085e+02
# rougher.state.floatbank10_f_level                  -6.499493e+02
# secondary_cleaner.output.tail_ag                    0.000000e+00
# secondary_cleaner.output.tail_pb                    0.000000e+00
# secondary_cleaner.output.tail_sol                   0.000000e+00
# secondary_cleaner.output.tail_au                    0.000000e+00
# secondary_cleaner.state.floatbank2_a_air            1.220129e-01
# secondary_cleaner.state.floatbank2_a_level         -7.996064e+02
# secondary_cleaner.state.floatbank2_b_air            0.000000e+00
# secondary_cleaner.state.floatbank2_b_level         -7.998739e+02
# secondary_cleaner.state.floatbank3_a_air            1.957942e-17
# secondary_cleaner.state.floatbank3_a_level         -7.995869e+02
# secondary_cleaner.state.floatbank3_b_air            1.521587e-17
# secondary_cleaner.state.floatbank3_b_level         -8.090495e+02
# secondary_cleaner.state.floatbank4_a_air            1.079872e-16
# secondary_cleaner.state.floatbank4_a_level         -7.997091e+02
# secondary_cleaner.state.floatbank4_b_air            2.489718e-17
# secondary_cleaner.state.floatbank4_b_level         -7.998891e+02
# secondary_cleaner.state.floatbank5_a_air           -3.720540e-01
# secondary_cleaner.state.floatbank5_a_level         -7.971425e+02
# secondary_cleaner.state.floatbank5_b_air            2.781642e+00
# secondary_cleaner.state.floatbank5_b_level         -8.000062e+02
# secondary_cleaner.state.floatbank6_a_air            1.273038e-01
# secondary_cleaner.state.floatbank6_a_level         -8.097415e+02
#
#                                                              25%  \
# final.output.concentrate_ag                             4.250499
# final.output.concentrate_pb                             9.158421
# final.output.concentrate_sol                            7.853530
# final.output.concentrate_au                            43.516822
# final.output.recovery                                  63.871619
# final.output.tail_ag                                    8.134250
# final.output.tail_pb                                    2.077418
# final.output.tail_sol                                   9.021832
# final.output.tail_au                                    2.480348
# primary_cleaner.input.sulfate                         118.168364
# primary_cleaner.input.depressant                        6.474037
# primary_cleaner.input.feed_size                         6.950000
# primary_cleaner.input.xanthate                          0.702067
# primary_cleaner.output.concentrate_ag                   7.384191
# primary_cleaner.output.concentrate_pb                   8.879277
# primary_cleaner.output.concentrate_sol                  7.946271
# primary_cleaner.output.concentrate_au                  30.439213
# primary_cleaner.output.tail_ag                         14.026222
# primary_cleaner.output.tail_pb                          2.519414
# primary_cleaner.output.tail_sol                         6.867291
# primary_cleaner.output.tail_au                          2.939690
# primary_cleaner.state.floatbank8_a_air               1503.504861
# primary_cleaner.state.floatbank8_a_level             -500.305939
# primary_cleaner.state.floatbank8_b_air               1503.182570
# primary_cleaner.state.floatbank8_b_level             -500.435983
# primary_cleaner.state.floatbank8_c_air               1500.834967
# primary_cleaner.state.floatbank8_c_level             -500.701519
# primary_cleaner.state.floatbank8_d_air               1498.360467
# primary_cleaner.state.floatbank8_d_level             -500.456950
# rougher.calculation.sulfate_to_au_concentrate       40924.425868
# rougher.calculation.floatbank10_sulfate_to_au_feed   2600.423019
# rougher.calculation.floatbank11_sulfate_to_au_feed   2546.489783
# rougher.calculation.au_pb_ratio                         2.041574
# rougher.input.feed_ag                                   7.305548
# rougher.input.feed_pb                                   2.927053
# rougher.input.feed_rate                               421.799926
# rougher.input.feed_size                                47.425354
# rougher.input.feed_sol                                 34.425245
# rougher.input.feed_au                                   6.949144
# rougher.input.floatbank10_sulfate                      10.030681
# rougher.input.floatbank10_xanthate                      5.496749
# rougher.input.floatbank11_sulfate                      10.001356
# rougher.input.floatbank11_xanthate                      5.500085
# rougher.output.concentrate_ag                          10.685547
# rougher.output.concentrate_pb                           6.722259
# rougher.output.concentrate_sol                         27.402183
# rougher.output.concentrate_au                          18.893369
# rougher.output.recovery                                81.553976
# rougher.output.tail_ag                                  4.923221
# rougher.output.tail_pb                                  0.481695
# rougher.output.tail_sol                                15.886710
# rougher.output.tail_au                                  1.412866
# rougher.state.floatbank10_a_air                       999.670744
# rougher.state.floatbank10_a_level                    -499.827278
# rougher.state.floatbank10_b_air                      1199.386162
# rougher.state.floatbank10_b_level                    -500.197680
# rougher.state.floatbank10_c_air                      1146.169245
# rougher.state.floatbank10_c_level                    -500.215101
# rougher.state.floatbank10_d_air                      1053.773874
# rougher.state.floatbank10_d_level                    -500.379476
# rougher.state.floatbank10_e_air                       998.602990
# rougher.state.floatbank10_e_level                    -500.227418
# rougher.state.floatbank10_f_air                       900.768337
# rougher.state.floatbank10_f_level                    -500.512490
# secondary_cleaner.output.tail_ag                       12.720295
# secondary_cleaner.output.tail_pb                        3.855135
# secondary_cleaner.output.tail_sol                       4.208046
# secondary_cleaner.output.tail_au                        3.181718
# secondary_cleaner.state.floatbank2_a_air               25.052148
# secondary_cleaner.state.floatbank2_a_level           -500.233672
# secondary_cleaner.state.floatbank2_b_air               20.828704
# secondary_cleaner.state.floatbank2_b_level           -500.252999
# secondary_cleaner.state.floatbank3_a_air               24.947859
# secondary_cleaner.state.floatbank3_a_level           -500.213321
# secondary_cleaner.state.floatbank3_b_air               18.995731
# secondary_cleaner.state.floatbank3_b_level           -500.122424
# secondary_cleaner.state.floatbank4_a_air               14.980941
# secondary_cleaner.state.floatbank4_a_level           -500.705018
# secondary_cleaner.state.floatbank4_b_air               11.944249
# secondary_cleaner.state.floatbank4_b_level           -500.184102
# secondary_cleaner.state.floatbank5_a_air               10.981557
# secondary_cleaner.state.floatbank5_a_level           -500.454615
# secondary_cleaner.state.floatbank5_b_air                8.966598
# secondary_cleaner.state.floatbank5_b_level           -500.130616
# secondary_cleaner.state.floatbank6_a_air               14.977066
# secondary_cleaner.state.floatbank6_a_level           -500.749262
#
#                                                              50%  \
# final.output.concentrate_ag                             5.051770
# final.output.concentrate_pb                            10.106536
# final.output.concentrate_sol                            9.310806
# final.output.concentrate_au                            45.055201
# final.output.recovery                                  68.459663
# final.output.tail_ag                                    9.820237
# final.output.tail_pb                                    2.770522
# final.output.tail_sol                                  10.646546
# final.output.tail_au                                    2.996648
# primary_cleaner.input.sulfate                         146.396911
# primary_cleaner.input.depressant                        8.081770
# primary_cleaner.input.feed_size                         7.282583
# primary_cleaner.input.xanthate                          0.973328
# primary_cleaner.output.concentrate_ag                   8.588337
# primary_cleaner.output.concentrate_pb                  10.205182
# primary_cleaner.output.concentrate_sol                 10.364264
# primary_cleaner.output.concentrate_au                  32.750843
# primary_cleaner.output.tail_ag                         15.849005
# primary_cleaner.output.tail_pb                          3.285553
# primary_cleaner.output.tail_sol                         8.257392
# primary_cleaner.output.tail_au                          3.618589
# primary_cleaner.state.floatbank8_a_air               1600.588684
# primary_cleaner.state.floatbank8_a_level             -499.928897
# primary_cleaner.state.floatbank8_b_air               1600.570032
# primary_cleaner.state.floatbank8_b_level             -499.958616
# primary_cleaner.state.floatbank8_c_air               1600.259011
# primary_cleaner.state.floatbank8_c_level             -499.912991
# primary_cleaner.state.floatbank8_d_air               1599.548337
# primary_cleaner.state.floatbank8_d_level             -499.916449
# rougher.calculation.sulfate_to_au_concentrate       44785.891120
# rougher.calculation.floatbank10_sulfate_to_au_feed   3009.196845
# rougher.calculation.floatbank11_sulfate_to_au_feed   2992.464768
# rougher.calculation.au_pb_ratio                         2.313183
# rougher.input.feed_ag                                   8.737431
# rougher.input.feed_pb                                   3.571752
# rougher.input.feed_rate                               499.658378
# rougher.input.feed_size                                54.503564
# rougher.input.feed_sol                                 37.309952
# rougher.input.feed_au                                   8.251421
# rougher.input.floatbank10_sulfate                      12.006929
# rougher.input.floatbank10_xanthate                      6.099171
# rougher.input.floatbank11_sulfate                      12.002466
# rougher.input.floatbank11_xanthate                      6.099784
# rougher.output.concentrate_ag                          12.179331
# rougher.output.concentrate_pb                           7.744306
# rougher.output.concentrate_sol                         29.926023
# rougher.output.concentrate_au                          20.324293
# rougher.output.recovery                                86.497667
# rougher.output.tail_ag                                  5.784718
# rougher.output.tail_pb                                  0.617977
# rougher.output.tail_sol                                18.135947
# rougher.output.tail_au                                  1.806395
# rougher.state.floatbank10_a_air                      1001.119023
# rougher.state.floatbank10_a_level                    -300.256196
# rougher.state.floatbank10_b_air                      1301.144429
# rougher.state.floatbank10_b_level                    -499.787169
# rougher.state.floatbank10_c_air                      1299.995940
# rougher.state.floatbank10_c_level                    -499.720130
# rougher.state.floatbank10_d_air                      1201.016684
# rougher.state.floatbank10_d_level                    -499.539100
# rougher.state.floatbank10_e_air                      1049.953750
# rougher.state.floatbank10_e_level                    -499.674782
# rougher.state.floatbank10_f_air                       999.832936
# rougher.state.floatbank10_f_level                    -499.486791
# secondary_cleaner.output.tail_ag                       15.699644
# secondary_cleaner.output.tail_pb                        5.333913
# secondary_cleaner.output.tail_sol                       7.685827
# secondary_cleaner.output.tail_au                        4.068600
# secondary_cleaner.state.floatbank2_a_air               29.091995
# secondary_cleaner.state.floatbank2_a_level           -499.975058
# secondary_cleaner.state.floatbank2_b_air               25.023156
# secondary_cleaner.state.floatbank2_b_level           -500.016110
# secondary_cleaner.state.floatbank3_a_air               27.985449
# secondary_cleaner.state.floatbank3_a_level           -499.932770
# secondary_cleaner.state.floatbank3_b_air               22.001627
# secondary_cleaner.state.floatbank3_b_level           -499.982972
# secondary_cleaner.state.floatbank4_a_air               18.017748
# secondary_cleaner.state.floatbank4_a_level           -499.845434
# secondary_cleaner.state.floatbank4_b_air               14.969316
# secondary_cleaner.state.floatbank4_b_level           -499.471037
# secondary_cleaner.state.floatbank5_a_air               14.987614
# secondary_cleaner.state.floatbank5_a_level           -499.800139
# secondary_cleaner.state.floatbank5_b_air               11.014904
# secondary_cleaner.state.floatbank5_b_level           -499.936350
# secondary_cleaner.state.floatbank6_a_air               19.952775
# secondary_cleaner.state.floatbank6_a_level           -500.056312
#
#                                                              75%           max
# final.output.concentrate_ag                             5.875022  1.600195e+01
# final.output.concentrate_pb                            11.043843  1.703190e+01
# final.output.concentrate_sol                           11.018236  1.961572e+01
# final.output.concentrate_au                            46.299552  5.157188e+01
# final.output.recovery                                  72.831400  1.000000e+02
# final.output.tail_ag                                   11.189927  1.955215e+01
# final.output.tail_pb                                    3.350265  5.804178e+00
# final.output.tail_sol                                  12.123213  2.227202e+01
# final.output.tail_au                                    3.575563  8.245022e+00
# primary_cleaner.input.sulfate                         177.373312  2.659831e+02
# primary_cleaner.input.depressant                       11.049561  2.005226e+01
# primary_cleaner.input.feed_size                         7.670000  1.550000e+01
# primary_cleaner.input.xanthate                          1.220788  4.102454e+00
# primary_cleaner.output.concentrate_ag                   9.862438  1.500579e+01
# primary_cleaner.output.concentrate_pb                  11.455024  1.708128e+01
# primary_cleaner.output.concentrate_sol                 13.508025  2.245811e+01
# primary_cleaner.output.concentrate_au                  34.927883  4.593393e+01
# primary_cleaner.output.tail_ag                         18.082279  2.945957e+01
# primary_cleaner.output.tail_pb                          4.220820  9.634565e+00
# primary_cleaner.output.tail_sol                         9.592996  2.227636e+01
# primary_cleaner.output.tail_au                          4.562392  1.778892e+01
# primary_cleaner.state.floatbank8_a_air               1697.494004  2.103104e+03
# primary_cleaner.state.floatbank8_a_level             -499.447235 -5.719540e+01
# primary_cleaner.state.floatbank8_b_air               1699.266022  1.825491e+03
# primary_cleaner.state.floatbank8_b_level             -499.385836 -1.425272e+02
# primary_cleaner.state.floatbank8_c_air               1699.445379  1.847622e+03
# primary_cleaner.state.floatbank8_c_level             -498.880584 -1.509370e+02
# primary_cleaner.state.floatbank8_d_air               1698.570097  2.398904e+03
# primary_cleaner.state.floatbank8_d_level             -499.122254 -3.060183e+01
# rougher.calculation.sulfate_to_au_concentrate       48139.967593  3.428099e+06
# rougher.calculation.floatbank10_sulfate_to_au_feed   3641.236103  6.296390e+05
# rougher.calculation.floatbank11_sulfate_to_au_feed   3568.031192  7.186850e+05
# rougher.calculation.au_pb_ratio                         2.736168  1.941039e+01
# rougher.input.feed_ag                                  10.297415  1.459603e+01
# rougher.input.feed_pb                                   4.275833  7.142594e+00
# rougher.input.feed_rate                               550.612917  7.175088e+02
# rougher.input.feed_size                                64.595770  4.849675e+02
# rougher.input.feed_sol                                 40.119250  5.347774e+01
# rougher.input.feed_au                                   9.853939  1.373133e+01
# rougher.input.floatbank10_sulfate                      14.987057  3.611827e+01
# rougher.input.floatbank10_xanthate                      6.800378  9.703448e+00
# rougher.input.floatbank11_sulfate                      14.979238  3.798065e+01
# rougher.input.floatbank11_xanthate                      6.801916  9.698407e+00
# rougher.output.concentrate_ag                          13.768886  2.172570e+01
# rougher.output.concentrate_pb                           8.562834  1.279777e+01
# rougher.output.concentrate_sol                         32.235125  3.835119e+01
# rougher.output.concentrate_au                          21.745573  2.882451e+01
# rougher.output.recovery                                90.148455  1.000000e+02
# rougher.output.tail_ag                                  6.397646  1.151244e+01
# rougher.output.tail_pb                                  0.774502  3.354033e+00
# rougher.output.tail_sol                                20.087639  6.561719e+01
# rougher.output.tail_au                                  2.203201  8.253282e+00
# rougher.state.floatbank10_a_air                      1292.818528  1.521980e+03
# rougher.state.floatbank10_a_level                    -299.980748 -2.737761e+02
# rougher.state.floatbank10_b_air                      1447.212124  1.807213e+03
# rougher.state.floatbank10_b_level                    -400.649947 -2.982001e+02
# rougher.state.floatbank10_c_air                      1448.996984  2.499129e+03
# rougher.state.floatbank10_c_level                    -401.022933 -2.921555e+02
# rougher.state.floatbank10_d_air                      1349.325656  1.817199e+03
# rougher.state.floatbank10_d_level                    -401.722564 -2.953707e+02
# rougher.state.floatbank10_e_air                      1198.397386  1.922637e+03
# rougher.state.floatbank10_e_level                    -401.253329 -2.721996e+02
# rougher.state.floatbank10_f_air                      1099.344495  1.706308e+03
# rougher.state.floatbank10_f_level                    -401.566698 -2.498010e+02
# secondary_cleaner.output.tail_ag                       17.410308  2.326474e+01
# secondary_cleaner.output.tail_pb                        7.810824  1.704250e+01
# secondary_cleaner.output.tail_sol                      10.267344  1.797617e+01
# secondary_cleaner.output.tail_au                        5.058053  2.681164e+01
# secondary_cleaner.state.floatbank2_a_air               32.999580  5.265140e+01
# secondary_cleaner.state.floatbank2_a_level           -499.680058 -1.669331e+02
# secondary_cleaner.state.floatbank2_b_air               28.003599  3.515212e+01
# secondary_cleaner.state.floatbank2_b_level           -499.788688 -2.119993e+02
# secondary_cleaner.state.floatbank3_a_air               32.995582  4.426046e+01
# secondary_cleaner.state.floatbank3_a_level           -499.341492 -1.916788e+02
# secondary_cleaner.state.floatbank3_b_air               26.001258  3.507284e+01
# secondary_cleaner.state.floatbank3_b_level           -499.816103 -1.597975e+02
# secondary_cleaner.state.floatbank4_a_air               23.006471  3.011574e+01
# secondary_cleaner.state.floatbank4_a_level           -498.267739 -2.452392e+02
# secondary_cleaner.state.floatbank4_b_air               18.944568  2.400791e+01
# secondary_cleaner.state.floatbank4_b_level           -400.120952 -2.965268e+01
# secondary_cleaner.state.floatbank5_a_air               18.020686  4.370993e+01
# secondary_cleaner.state.floatbank5_a_level           -498.405399 -2.444836e+02
# secondary_cleaner.state.floatbank5_b_air               14.007033  2.792600e+01
# secondary_cleaner.state.floatbank5_b_level           -499.441148 -1.377400e+02
# secondary_cleaner.state.floatbank6_a_air               23.029692  3.218891e+01
# secondary_cleaner.state.floatbank6_a_level           -499.503375 -1.044275e+02

# %% [markdown]
# **Проверим наличие дубликатов**

# %%
gold_full.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Преобразуем тип столбца `date` в datetime

# %%
gold_test['date'] = pd.to_datetime(gold_test['date'], format='%Y-%m-%d %H:%M:%S')

# %%
gold_train['date'] = pd.to_datetime(gold_full['date'], format='%Y-%m-%d %H:%M:%S')

# %%
gold_full['date'] = pd.to_datetime(gold_full['date'], format='%Y-%m-%d %H:%M:%S')

# %% [markdown]
# ### Вывод
#
# Имеются данные с параметрами добычи и очистки золотосодержащей руды\
# Модель должна предсказать коэффициент восстановления золота из золотосодержащей руды.
#
# **Признаки**\
# признаки совпадают с параметрами таблицы `gold_test`\
# **Целевые признаки**\
# `rougher.output.recovery` — эффективность обогащения чернового концентрата\
# `final.output.recovery` — эффективность обогащения финального концентрата\
#
# 1) Первый столбец всех таблиц имеет формат object, хотя содержит дату и время, его можно перевести в формат datetime (преобразовали)\
# 2) В таблице `gold_test` меньше столбцов, чем в остальных таблицах (53 вместо 87)\
# 3) В таблицах есть пропуски значений\
# 4) Значения в столбце `rougher.output.recovery` совпадают, что может свидетельствовать о том, что величина в столбце `rougher.output.recovery` рассчитывается по той же формуле, на основе данных в столбцах `rougher.output.concentrate_au`, `rougher.input.feed_au` и `rougher.output.tail_au`\
# 5) В тестовой выборке отсутствуют значения параметров продукта (выходные значения) для всех этапов технологического процесса (флотация, первичная очистка, вторичная очистка, финальные характеристики).\
# 6) В тестовой выборке нет параметров `feed`, необходимых для проверки размеров гранул сырья.\
# 7) Доля пропущенных значений не превышала 10% для параметра `secondary_cleaner.output.tail_sol`. Для 2 параметров `rougher.input.floatbank11_xanthate`  и `rougher.state.floatbank10_e_air` доля пропусков не более 3%,  доля пропусков в остальных параметрах не превышала 2%.\
# 8) Пропуски параметра `secondary_cleaner.output.tail_sol` были заполнены медианными значениями, пропуски параметров `rougher.input.floatbank11_xanthate`  и `rougher.state.floatbank10_e_air` были заполнены средними значениями, остальные пропуски были удалены (не более 7% от общего объема выборки).\
# 9) Дубликатов в данных не обнаружено\
# 10) Категориальных признаков не обнаружено

# %% [markdown]
# ## Анализ данных

# %% [markdown]
# **Посмотрим, как меняется концентрация металлов (Au, Ag, Pb) на различных этапах очистки**

# %% [markdown]
# Напишем функцию для поиска концентраций металлов на разных стадиях технологического процесса

# %%
def concentrate (metal):
    df = gold_full.mean()
    calc = [col for col in gold_full.columns if metal in col]
    conc = [col for col in calc if 'calcul' not in col]
    return df[conc].sort_values()

# %% [markdown]
# Посмотрим, как меняется концентрация золота на различных этапах очистки

# %%
au = concentrate('au')
au
# Out:
# rougher.output.tail_au                    1.813808
# final.output.tail_au                      3.059904
# primary_cleaner.output.tail_au            3.886339
# secondary_cleaner.output.tail_au          4.312568
# rougher.input.feed_au                     8.395574
# rougher.output.concentrate_au            19.832956
# primary_cleaner.output.concentrate_au    32.117867
# final.output.concentrate_au              44.342318
# dtype: float64

# %% [markdown]
# Посмотрим, как меняется концентрация серебра на различных этапах очистки

# %%
ag = concentrate('ag')
ag
# Out:
# final.output.concentrate_ag               5.160709
# rougher.output.tail_ag                    5.606673
# primary_cleaner.output.concentrate_ag     8.541476
# rougher.input.feed_ag                     8.881569
# final.output.tail_ag                      9.766414
# rougher.output.concentrate_ag            12.036312
# secondary_cleaner.output.tail_ag         14.656572
# primary_cleaner.output.tail_ag           16.202679
# dtype: float64

# %% [markdown]
# Посмотрим, как меняется концентрация свинца на различных этапах очистки

# %%
pb = concentrate('pb')
pb
# Out:
# rougher.output.tail_pb                    0.644467
# final.output.tail_pb                      2.733293
# primary_cleaner.output.tail_pb            3.463051
# rougher.input.feed_pb                     3.634480
# secondary_cleaner.output.tail_pb          5.789204
# rougher.output.concentrate_pb             7.607875
# primary_cleaner.output.concentrate_pb     9.944044
# final.output.concentrate_pb              10.021711
# dtype: float64

# %% [markdown]
# 1) Концентрация золота от этапа к этапу увеличивается с 8.4 в среднем, до 44.3. Концентрация золота в хвостах изменяется от 1.8 до 3.1 в среднем и в целом выглядит стабильно.
#
# 2) Концентрация серебра в основной массе изменяется от 8.9 до 5.2 и в целом выглядит стабильно. Концентрация серебра в хвостах увеличивается от 5.6 на начальных этапах до 14-16 в середине процесса и снижается до 9.8 на финальном этапе.
#
# 3) Концентрация свинца в основной массе увеличивается с 0.6 до 10 в среднем. Концентрация свинца в хвостах увеличивается от 0.6 на начальных этапах до 3-6 в середине процесса и снижается до 2.7 на финальном этапе.

# %% [markdown]
# **Сравним распределения размеров гранул сырья на обучающей и тестовой выборках. Если распределения сильно отличаются друг от друга, оценка модели будет неправильной**

# %% [markdown]
# Создадим функцию для поиска всех столбцов содержащих `feed_size`

# %%
def feed_size (df):
    df = df.mean()
    feed = [col for col in gold_full.columns if 'feed_size' in col]
    return df[feed].sort_values()

# %% [markdown]
# Проверим размеров гранул сырья на обучающей выборке

# %%
feed_size_train = feed_size(gold_train)

# %% [markdown]
# Проверим размеров гранул сырья на тестовой выборке

# %%
feed_size_test = feed_size(gold_test)
feed_size_test
# Out:
# primary_cleaner.input.feed_size     7.278842
# rougher.input.feed_size            55.262457
# dtype: float64

# %% [markdown]
# Посчитаем разницу между размерами гранул в обучающей и тестовой выборках

# %%
delta_feed_size = ((feed_size_train - feed_size_test) / feed_size_test ) * 100
delta_feed_size
# Out:
# primary_cleaner.input.feed_size    0.735587
# rougher.input.feed_size            8.102835
# dtype: float64

# %% [markdown]
# Размер гранул на этапе `rougher` для тестовой выборки на 8.1% больше, чем размер гранул на обучающей выборке. Для этапа `primary_cleaner` размер гранул на тестовой выборке на 0.7% больше, чем размер гранул на обучающей выборке.

# %% [markdown]
# **Исследуем суммарную концентрацию всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах**

# %% [markdown]
# Создадим функцию для поиска всех столбцов содержащих концентрации веществ на всех стадия технологического процесса

# %%
def total_concentration(df):
    df = df.mean()
    concentration = [col for col in gold_full.columns if 'concen' in col]
    rougher = [col for col in concentration if 'rougher' in col]
    primary = [col for col in concentration if 'primary' in col]
    final = [col for col in concentration if 'final' in col]
    drop = df[rougher].drop('rougher.calculation.sulfate_to_au_concentrate') 
    print('Суммарная концентрация всех веществ на этапе сырья: ', round(drop.sum(), 2),'\n',
          'Cуммарная концентрация всех веществ на черновом этапе: ', round(df[primary].sum(), 2),'\n',  
          'Cуммарная концентрация всех веществ на финальном этапе: ', round(df[final].sum(), 2))

# %%
total_concentration(gold_full)
# Out:
# Суммарная концентрация всех веществ на этапе сырья:  68.41
#  Cуммарная концентрация всех веществ на черновом этапе:  61.16
#  Cуммарная концентрация всех веществ на финальном этапе:  69.14

# %% [markdown]
# Концентрации всех веществ находятся на уровне от 61 до 69, минимальное значение достигается на черновом этапе (61).

# %% [markdown]
# ### Вывод
#
# 1) Концентрация золота от этапа к этапу увеличивается с 8.4 в среднем, до 44.3. Концентрация золота в хвостах изменяется от 1.8 до 3.1 в среднем и в целом выглядит стабильно.
#
# 2) Концентрация серебра в основной массе изменяется от 8.9 до 5.2 и в целом выглядит стабильно. Концентрация серебра в хвостах увеличивается от 5.6 на начальных этапах до 14-16 в середине процесса и снижается до 9.8 на финальном этапе.
#
# 3) Концентрация свинца в основной массе увеличивается с 0.6 до 10 в среднем. Концентрация свинца в хвостах увеличивается от 0.6 на начальных этапах до 3-6 в середине процесса и снижается до 2.7 на финальном этапе.
#
# 4) Размер гранул на этапе rougher для тестовой выборки на 8.1% больше, чем размер гранул на обучающей выборке. Для этапа primary_cleaner размер гранул на тестовой выборке на 0.7% больше, чем размер гранул на обучающей выборке.
#
# 5) Cуммарная концентрация всех веществ на этапе сырья:  68.41
#
# 6)  Cуммарная концентрация всех веществ на черновом этапе:  61.16
#
# 7) Cуммарная концентрация всех веществ на финальном этапе:  69.14

# %% [markdown]
# ## Модель

# %% [markdown]
# Создадим функцию для вычисления итоговой sMAPE

# %%
def smape(target, predict):
    return 100/len(target) * np.sum(2 * np.abs(predict - target) / (np.abs(target) + np.abs(predict)))

# %% [markdown]
# Создадим метрику качества на основе нашей функции sMAPE

# %%
my_scorer = make_scorer(smape,  greater_is_better=False)

# %% [markdown]
# Создадим функцию для подсчета итоговой sMAPE

# %%
# sMAPE(rougher.output.recovery).25 + sMAPE(final.output.recovery).75
def full_smape(score_final, score_rougher):
    return score_rougher * .25 + score_final * .75

# %% [markdown]
# Разделим обучающую выборку на `features_train` и `target_train`

# %%
t = gold_train.drop(dif_tables, axis=1)
features_train = t.drop('date', axis=1)

# %%
target_train = gold_train['final.output.recovery']

# %% [markdown]
# Разделим тестовую выборку на `features_test` и `target_test`

# %%
t = gold_test.drop(dif_tables, axis=1)
features_test = t.drop('date', axis=1)

# %%
target_test = gold_test['final.output.recovery']

# %% [markdown]
# Выделим параметры для чернового концентрата

# %%
def rougher(df):
    roug = [col for col in df.columns if 'rougher' in col]
    return df[roug]

# %% [markdown]
# Разделим обучающую выборку на `features_train` и `target_train` для  чернового концентрата

# %%
features_train_r = rougher(features_train)

# %%
target_train_r = gold_train['rougher.output.recovery']

# %% [markdown]
# Разделим тестовую выборку на `features_test` и `target_test` для чернового концентрата

# %%
features_test_r = rougher(features_test)

# %%
target_test_r = gold_test['rougher.output.recovery']

# %%
features_train_r.head()
# Out:
#    rougher.input.feed_ag  rougher.input.feed_pb  rougher.input.feed_rate  \
# 0               6.100378               2.284912               523.546326
# 1               6.161113               2.266033               525.290581
# 2               6.116455               2.159622               530.026610
# 3               6.043309               2.037807               542.590390
# 4               6.060915               1.786875               540.531893
#
#    rougher.input.feed_size  rougher.input.feed_sol  rougher.input.feed_au  \
# 0                55.486599               36.808594               6.486150
# 1                57.278666               35.753385               6.478583
# 2                57.510649               35.971630               6.362222
# 3                57.792734               36.862241               6.118189
# 4                56.047189               34.347666               5.663707
#
#    rougher.input.floatbank10_sulfate  rougher.input.floatbank10_xanthate  \
# 0                          11.986616                            6.007990
# 1                          11.971193                            6.005766
# 2                          11.920603                            6.197377
# 3                          11.630094                            6.203177
# 4                          10.957755                            6.198826
#
#    rougher.input.floatbank11_sulfate  rougher.input.floatbank11_xanthate  ...  \
# 0                          11.836743                            6.005818  ...
# 1                          11.996163                            6.012594  ...
# 2                          11.920305                            6.204633  ...
# 3                          11.692450                            6.196578  ...
# 4                          10.960521                            6.194897  ...
#
#    rougher.state.floatbank10_b_air  rougher.state.floatbank10_b_level  \
# 0                      1603.011353                        -434.715027
# 1                      1600.754587                        -449.953435
# 2                      1599.337330                        -450.008530
# 3                      1600.059442                        -450.619948
# 4                      1600.208824                        -449.599614
#
#    rougher.state.floatbank10_c_air  rougher.state.floatbank10_c_level  \
# 0                      1602.375000                        -442.204468
# 1                      1600.479580                        -449.830646
# 2                      1599.672797                        -449.954491
# 3                      1600.012842                        -449.910497
# 4                      1600.357732                        -450.034364
#
#    rougher.state.floatbank10_d_air  rougher.state.floatbank10_d_level  \
# 0                      1598.937256                        -451.294128
# 1                      1600.527589                        -449.953649
# 2                      1599.849325                        -449.954185
# 3                      1597.725177                        -450.130127
# 4                      1599.759049                        -449.909799
#
#    rougher.state.floatbank10_e_air  rougher.state.floatbank10_e_level  \
# 0                      1404.472046                        -455.462982
# 1                      1399.227084                        -450.869848
# 2                      1399.180945                        -449.937588
# 3                      1400.943157                        -450.030142
# 4                      1401.560902                        -448.877187
#
#    rougher.state.floatbank10_f_air  rougher.state.floatbank10_f_level
# 0                      1416.354980                        -451.939636
# 1                      1399.719514                        -450.119001
# 2                      1400.316682                        -450.527147
# 3                      1400.234743                        -449.790835
# 4                      1401.160227                        -450.407128
#
# [5 rows x 22 columns]

# %% [markdown]
# Масштабируем признаки для обучения

# %%
scaler = StandardScaler()
scaler.fit(features_train)
features_train = scaler.transform(features_train)
features_test = scaler.transform(features_test)

# %%
features_train.shape
# Out:
# (13005, 52)

# %%
features_test.shape
# Out:
# (5159, 52)

# %%
features_test_r.shape
# Out:
# (5159, 22)

# %%
features_train_r.shape
# Out:
# (13005, 22)

# %% [markdown]
# Обучим модель линейной регрессии для расчета эффективности обогащения финального концентрата с учетом кросс валидации

# %%
# %%time
estimator = LinearRegression()
param_grid = {'fit_intercept':[True,False], 
              'normalize':[True,False], 
              'copy_X':[True, False], 
              'positive':[True, False]}
grid = GridSearchCV(estimator, param_grid, scoring=my_scorer, cv=5)
grid.fit(features_train, target_train)
predict = grid.best_estimator_.predict(features_test)
best_score_l = smape(target_test, predict)
print('Параметры лучшей модели: ', grid.best_params_)
print('sMAPE лучшей модели: ', best_score_l,'\n')
# Out:
# Параметры лучшей модели:  {'copy_X': True, 'fit_intercept': True, 'normalize': False, 'positive': True}
# sMAPE лучшей модели:  8.054786407515374
#
# CPU times: user 24.6 s, sys: 731 ms, total: 25.3 s
# Wall time: 3.4 s

# %% [markdown]
# Обучим модель Дерево решений для расчета эффективности обогащения финального концентрата с учетом кросс валидации

# %%
# %%time
estimator = DecisionTreeRegressor(random_state=42)
param_grid = {'max_depth': range(1,10,1)} 
grid = GridSearchCV(estimator, param_grid, scoring=my_scorer, cv=5)
grid = grid.fit(features_train, target_train)
best_score_t = smape(target_test, grid.best_estimator_.predict(features_test))
print('Параметры лучшей модели: ', grid.best_params_)
print('sMAPE лучшей модели: ', best_score_t,'\n')
# Out:
# Параметры лучшей модели:  {'max_depth': 4}
# sMAPE лучшей модели:  9.308444810738909
#
# CPU times: user 14.1 s, sys: 185 ms, total: 14.3 s
# Wall time: 12.8 s

# %% [markdown]
# Обучим модель Случайный лес для расчета эффективности обогащения финального концентрата с учетом кросс валидации

# %%
# %%time
estimator = RandomForestRegressor(random_state=42)
para_grids = {'n_estimators': range(60,100,10), 
              'max_depth': range(2,9,2)} 
grid = GridSearchCV(estimator, para_grids, cv=5)
grid = grid.fit(features_train, target_train)
best_score_f = smape(target_test, grid.best_estimator_.predict(features_test))
print('Параметры лучшей модели: ', grid.best_params_)
print('sMAPE лучшей модели: ', best_score_f,'\n')
# Out:
# Параметры лучшей модели:  {'max_depth': 4, 'n_estimators': 70}
# sMAPE лучшей модели:  8.418650492333555
#
# CPU times: user 16min 52s, sys: 2.21 s, total: 16min 54s
# Wall time: 16min 54s

# %% [markdown]
# Лучшие значения sMAPE показала модель линейной регрессии, так же это достаточно быстрая модель
#
# Для дальнейших расчетов эффективности обогащения чернового концентрата будем использовать модель линейной регрессии

# %% [markdown]
# Обучим модель линейной регрессии для расчета эффективности обогащения чернового концентрата

# %%
# %%time
estimator = LinearRegression()
param_grid = {'fit_intercept':[True,False], 
              'normalize':[True,False], 
              'copy_X':[True, False], 
              'positive':[True, False]}
grid = GridSearchCV(estimator, param_grid, scoring=my_scorer, cv=5)
grid.fit(features_train_r, target_train_r)
predict = grid.predict(features_test_r)
best_score_l_r = smape(target_test_r, predict)
print('Параметры лучшей модели: ', grid.best_params_)
print('sMAPE лучшей модели: ', best_score_l_r,'\n')
# Out:
# Параметры лучшей модели:  {'copy_X': True, 'fit_intercept': True, 'normalize': True, 'positive': True}
# sMAPE лучшей модели:  8.371717902483791
#
# CPU times: user 11.1 s, sys: 335 ms, total: 11.5 s
# Wall time: 1.56 s

# %% [markdown]
# Посчитаем итоговую метрику для линейной регресии

# %%
full_smape(best_score_l_r, best_score_l)
# Out:
# 8.292485028741687

# %% [markdown]
# Проверим адекватность модели на DummyRegressor

# %% [markdown]
# DummyRegressor для финального концентрата

# %%
dummy_regr = DummyRegressor(strategy="mean")
dummy_regr.fit(features_train, target_train)
DummyRegressor()
predict = dummy_regr.predict(features_test)
dummy = smape(target_test_r, predict)
print('sMAPE Dummy модели: ', dummy)
# Out:
# sMAPE Dummy модели:  28.86935361168233

# %% [markdown]
# DummyRegressor для чернового концентрата

# %%
dummy_regr = DummyRegressor(strategy="mean")
dummy_regr.fit(features_train_r, target_train_r)
DummyRegressor()
predict = dummy_regr.predict(features_test_r)
dummy_r = smape(target_test_r, predict)
print('sMAPE Dummy модели: ', dummy_r)
# Out:
# sMAPE Dummy модели:  9.85871699379236

# %% [markdown]
# Итоговый sMAPE для модели DummyRegressor

# %%
full_smape(dummy_r, dummy)
# Out:
# 14.611376148264853

# %% [markdown]
# ### Вывод
#
# 1) Создали функцию для вычисления sMAPE
#
# 2) Отмасштабировали признаки для обучения
#
# 3) Обучили 3 модели машинного обучения: Линейная регрессия, Решающее дерево и Случайный лес
#
# 4) Лучшие параметры для линейной регрессии :  {'copy_X': True, 'fit_intercept': True, 'normalize': False, 'positive': True}
# sMAPE лучшей модели:  8.05
#
# 5) Лучшие параметры для дерева решений:  {'max_depth': 4}
# sMAPE лучшей модели:  9.30
#
# 6) Лучшие параметры для случайного леса:  {'max_depth': 4, 'n_estimators': 70}
# sMAPE лучшей модели:  8.41
#
# 7) Лучшие параметры для линейной регрессии  в расчете эффективности обогащения чернового концентрата:
# {'copy_X': True, 'fit_intercept': True, 'normalize': True, 'positive': True}
# sMAPE лучшей модели:  8.37
#
# 8) Итоговое значение sMAPE - 8.29, что практически в 2 раза лучше, чем модель DummyRegressor

# %% [markdown]
# ## Общий вывод
#
# Имеются данные с параметрами добычи и очистки золотосодержащей руды
#
# Модель должна предсказать коэффициент восстановления золота из золотосодержащей руды.
#
# Признаки:
#
# признаки совпадают с параметрами таблицы `gold_test`
#
# Целевые признаки:
#
# `rougher.output.recovery` — эффективность обогащения чернового концентрата
#
# `final.output.recovery` — эффективность обогащения финального концентрата
#
# 1) Первый столбец всех таблиц имеел формат object, хотя содержит дату и время, преобразовали его в формат datetime\
# 2) В таблице gold_test меньше столбцов, чем в остальных таблицах (53 вместо 87)\
# 3) В таблицах есть пропуски значений\
# 4) Значения в столбце `rougher.output.recovery` совпадают, что может свидетельствовать о том, что величина в столбце `rougher.output.recovery` раситывается по той же формуле, на основе данных в столбцах `rougher.output.concentrate_au`, `rougher.input.feed_au` и `rougher.output.tail_au`\
# 5) В тестовой выборке отсутствуют значения параметров продукта (выходные значения) для всех этапов технологического процесса (флотация, первичная очистка, вторичная очистка, финальные характеристики)\
# 6) В тестовой выборке нет параметров `feed`, необходимых для проверки размеров гранул сырья\
# 7) Доля пропущенных значений не превышала 10% для параметра `secondary_cleaner.output.tail_sol`. Для 2 параметров `rougher.input.floatbank11_xanthate` и `rougher.state.floatbank10_e_air` доля пропусков не более 3%, доля пропусков в остальных параметрах не превышала 2%\
# 8) Пропуски параметра `secondary_cleaner.output.tail_sol` были заполнены медианными значениями, пропуски параметров `rougher.input.floatbank11_xanthate` и `rougher.state.floatbank10_e_air` были заполнены средними значениями, остальные пропуски были удалены (не более 7% от общего объема выборки)\
# 9) Дубликатов в данных не обнаружено\
# 10) Категориальных признаков не обнаружено\
# 11) Концентрация золота от этапа к этапу увеличивается с 8.4 в среднем, до 44.3. Концентрация золота в хвостах изменяется от 1.8 до 3.1 в среднем и в целом выглядит стабильно\
# 12) Концентрация серебра в основной массе изменяется от 8.9 до 5.2 и в целом выглядит стабильно. Концентрация серебра в хвостах увеличивается от 5.6 на начальных этапах до 14-16 в середине процесса и снижается до 9.8 на финальном этапе\
# 13) Концентрация свинца в основной массе увеличивается с 0.6 до 10 в среднем. Концентрация свинца в хвостах увеличивается от 0.6 на начальных этапах до 3-6 в середине процесса и снижается до 2.7 на финальном этапе\
# 14) Размер гранул на этапе rougher для тестовой выборки на 8.1% больше, чем размер гранул на обучающей выборке. Для этапа primary_cleaner размер гранул на тестовой выборке на 0.7% больше, чем размер гранул на обучающей выборке\
# 15) Cуммарная концентрация всех веществ на этапе сырья: 68.41\
# 16) Cуммарная концентрация всех веществ на черновом этапе: 61.16\
# 17) Cуммарная концентрация всех веществ на финальном этапе: 69.14\
# 18) Создали функцию для вычисления sMAPE\
# 19) Отмасштабировали признаки для обучения\
# 20) Обучили 3 модели машинного обучения: Линейная регрессия, Решающее дерево и Случайный лес\
# 21) Лучшие параметры для линейной регрессии : {'copy_X': True, 'fit_intercept': True, 'normalize': False, 'positive': True} sMAPE лучшей модели: 8.05\
# 22) Лучшие параметры для дерева решений: {'max_depth': 4} sMAPE лучшей модели: 9.30\
# 23) Лучшие параметры для случайного леса: {'max_depth': 4, 'n_estimators': 70} sMAPE лучшей модели: 8.41\
# 24) Лучшие параметры для линейной регрессии в расчете эффективности обогащения чернового концентрата: {'copy_X': True, 'fit_intercept': True, 'normalize': True, 'positive': True} sMAPE лучшей модели: 8.37\
# 25) Итоговое значение sMAPE - 8.29, что практически в 2 раза лучше, чем модель DummyRegressor
